# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day112.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basics of TensorFlow**
#
# - Tensor and Operations
#
#   - Introduction to Tensors
#
#   - What are Tensors?
#
#     - Scalar(Rank-0 Tensor)
#
#     - Vector(Rank-1 Tensor)
#
#     - Matrix(Rank-2 Tensor)
#
#     - Higher-Rank Tensors:
#
# - Properties of Tensors
#
#   - Shape
#
#   - DataType(dtype)
#
#   - Values
