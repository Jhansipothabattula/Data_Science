# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day129.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Applications of RNNs

# %% [markdown]
# * **Language Modeling**
#   * Text Generation
#   * Machine Translation
#   * Speech Recognition
#   * Sentiment Analysis
#
#
# * **Time Series Prediction**
#   * Stock Market Prediction
#   * Weather Forecasting
#   * Demand Forecasting
#   * Healthcare Forecasting
