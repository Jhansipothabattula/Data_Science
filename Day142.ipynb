# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day142.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Detection

# %% [markdown]
# **Practical Applications and Projects**
#
# **Real-world Applications: Object Detection**
#
# 1. Autonomous Vehicles
#     * Pedestrian Detection
#     * Traffic Sign Recognition
#
#
# 2. Surveillance and Security
#     * Intrusion Detection
#     * Object Tracking
#
#
# 3. Retail and Inventory Management
#     * Customer Tracking
#     * Shelf Monitoring
#
#
# 4. Industrial Automation
#     * Defect Detection
#     * Object Sorting and Handling
#
#
# 5. Healthcare
#     * Medical Imaging Analysis
#     * Surgical Assistance
