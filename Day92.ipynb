# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# **K-Means Clustering**
#
# K-Means Clustering is an unsupervised learning algorithm that partitions data into k clusters. Each cluster is defined by its centroid, and each data point is assigned to the nearest cluster. The algorithm iteratively adjusts centroids to minimize the variance within each cluster

# %%
# Import necessary libraries
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# Sample data (e.g., points in 2D space)
X = np.array([[1, 2], [1, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])

# Initialize and fit the model
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)

# Get the cluster centers and labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

print("Cluster Centers:\n", centroids)
print("Labels:", labels)

# Plotting Code
plt.figure(figsize=(8, 5))

# Plot the data points, coloring them by their cluster label
plt.scatter(X[:, 0], X[:, 1], c=labels, s=100, cmap='viridis', label='Data Points')

# Plot the centroids as large red 'X' marks
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, marker='X', label='Centroids')

# Formatting the plot
plt.title('K-Means Clustering: Data Points and Centroids')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# Cluster Centers:
#  [[ 1.  2.]
#  [10.  2.]]
# Labels: [0 0 0 1 1 1]
