# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DBSCAN(Density-Based Spatial Clustering of Applications with Noise)

# %% [markdown]
# **DBSCAN**
#
# DBSCAN is an unsupervised clustering algorithm that groups data points based on density, making it particularly effective for identifying clusters of arbitrary shapes and for handling noise (outliers). DBSCAN requires two parameters: eps (the maximum distance between two points to be considered neighbors) and min_samples (the minimum number of points required to form a dense region)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# 1. Sample data from your screenshot
X = np.array([[1, 2], [2, 2], [2, 3], [8, 7], [8, 8], [25, 80]])

# 2. Initialize and fit the model
# eps=3: max distance between neighbors; min_samples=2: min points for a cluster
dbscan = DBSCAN(eps=3, min_samples=2)
dbscan.fit(X)

# 3. Get labels (-1 indicates noise/outliers)
labels = dbscan.labels_

# Plotting Code
plt.figure(figsize=(10, 6))

# Unique labels in our data (including -1 for noise)
unique_labels = set(labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]
        label_name = 'Noise'
    else:
        label_name = f'Cluster {k}'

    class_member_mask = (labels == k)
    xy = X[class_member_mask]

    plt.scatter(xy[:, 0], xy[:, 1], c=[col], s=100, edgecolors='k', label=label_name)

plt.title('DBSCAN Clustering: Clusters and Noise Identification')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
